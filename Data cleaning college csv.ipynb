# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("./2015_16_college_institution.csv")
# Out:
# /home/ambika/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data=data.drop(columns=['area','constructed_area','year_of_establishment','nodalofficer_id','statutory_body_id','other_statutory_body','year_of_affiliation'
                       ,'management_id','offers_loan','staff_quarter_available','staff_quarter_id','financial_income_id','financial_expenditure_id',
                       'other_speciality','survey_year','remarks','scholarship_id','loan_id','is_accredited','is_foreign_students_enrolled','has_diploma_courses','diploma_course_id',
                        'fellowships_id','other_affiliated_university_id','has_other_minority_data'])

# %%
data.head()
# Out:
#       id                                      address_line1  \
# 0  34256                                         aurangabad
# 1  55441  VILL- SAHUBAHIYAR,  P.O- TOPCHANCHI, P.S- TOPC...
# 2  22449                                  Bhuna Road Tohana
# 3  13438                   DHAMPUR DEGREE COLLEGE , DHAMPUR
# 4  13376                      dhampur law college , DHAMPUR
#
#                                 address_line2        city  state_code  \
# 0  P.Box 968 Bajajnagar MIDC WAluj Aurangabad  South City          27
# 1                               DIST- DHANBAD     DHANBAD          20
# 2                           Bhuna Road Tohana      Tohana           6
# 3                      PAHARI DARWAZA DHAMPUR     DHAMPUR           9
# 4                      pahari darwaza dhampur     dhampur           9
#
#    district_code                     website  university_id location  \
# 0            515             www.yash.org.in            298        R
# ...

# %%
data.columns
# Out:
# Index(['id', 'address_line1', 'address_line2', 'city', 'state_code',
#        'district_code', 'website', 'university_id', 'location', 'autonomous',
#        'specialized', 'evening', 'girl_exclusive', 'student_hostel_available',
#        'no_of_student_hostel', 'speciality_id', 'name', 'infrastructure_id',
#        'latitude', 'longitude', 'offers_scholarship', 'college_type_id',
#        'pin_code', 'has_fellowships'],
#       dtype='object')

# %%
data=data.drop(columns=['address_line1','address_line2','district_code','website','autonomous','specialized','evening','girl_exclusive'
               ,'speciality_id','college_type_id','pin_code','has_fellowships','student_hostel_available','location'])

# %%
data
# Out:
#           id             city  state_code  university_id  \
# 0      34256       South City          27            298
# 1      55441          DHANBAD          20            212
# 2      22449           Tohana           6            160
# 3      13438          DHAMPUR           9            525
# 4      13376          dhampur           9            525
# 5       8719   Dist-Darbhanga          10             68
# 6      51928      BIHARSHARIF          10             69
# 7      55446           BOKARO          20            212
# 8      52219              NaN           9            550
# 9      51402         HASANPUR           9            525
# 10     29284       Chandigarh           4             78
# 11     54826             AGRA           9            509
# 12     52242           RAIPUR          22             81
# 13     36831     NEW GHARSANA           8            406
# 14     46142            HAPUR           9            549
# ...

# %%
# data=data.dropna(subset=['latitude'])

# %%
# data

# %%
# data.reset_index()

# %%
# data.shape

# %%
data=data.applymap(func=lambda x: 1 if x == True else x)
data=data.applymap(func=lambda x: 0 if x == False else x)

# %%
data.head()
# Out:
#       id        city  state_code  university_id  no_of_student_hostel  \
# 0  34256  South City          27            298                     0
# 1  55441     DHANBAD          20            212                     0
# 2  22449      Tohana           6            160                     2
# 3  13438     DHAMPUR           9            525                     0
# 4  13376     dhampur           9            525                     0
#
#                                                 name  infrastructure_id  \
# 0   Yash Institute of Pharmacy waluj road Aurangabad             189205
# 1  Binod bihari Mahato Memorial teachers Training...             209799
# 2                Defence College of Educaton, Tohana             209800
# 3                    Dhampur Degree College, Dhampur             209801
# 4                       Dhampur Law College, Dhampur             209802
#
#     latitude  longitude  offers_scholarship
# 0  19.530001  75.230001                   1
# ...

# %%
data=data.to_csv('college_institution.csv')

# %%
data=pd.read_csv("./college_institution.csv")

# %%
# data.set_index('university_id')

# %%
data.loc[data['university_id']==99]
# Out:
#        Unnamed: 0     id              city  state_code  university_id  \
# 249           249  32917  New Delhi-110070           7             99
# 1625         1625  32866         New Delhi           7             99
# 2197         2197  32865         Hauz Khas           7             99
# 2854         2854  32837         New Delhi           7             99
# 2955         2955  32856             Delhi           7             99
# 6027         6027  32911         New Delhi           7             99
# 7429         7429  32901     Greater Noida           9             99
# 7721         7721  32870             DELHI           7             99
# 9373         9373  32845             DELHI           7             99
# 9668         9668  32924             DELHI           7             99
# 10088       10088  32929         New Delhi           7             99
# 10324       10324  32842         New Delhi           7             99
# ...
