# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("./2015_16_college_institution.csv")
# Out:
# /home/ambika/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# data=data.values
# Out:
#       id                                      address_line1  \
# 0  34256                                         aurangabad
# 1  55441  VILL- SAHUBAHIYAR,  P.O- TOPCHANCHI, P.S- TOPC...
# 2  22449                                  Bhuna Road Tohana
# 3  13438                   DHAMPUR DEGREE COLLEGE , DHAMPUR
# 4  13376                      dhampur law college , DHAMPUR
#
#                                 address_line2        city  state_code  \
# 0  P.Box 968 Bajajnagar MIDC WAluj Aurangabad  South City          27
# 1                               DIST- DHANBAD     DHANBAD          20
# 2                           Bhuna Road Tohana      Tohana           6
# 3                      PAHARI DARWAZA DHAMPUR     DHAMPUR           9
# 4                      pahari darwaza dhampur     dhampur           9
#
#    district_code                     website   area  constructed_area  \
# 0            515             www.yash.org.in   2.50              45.2
# ...

# %%
data.head()
# Out:
#       id                                      address_line1  \
# 0  34256                                         aurangabad
# 1  55441  VILL- SAHUBAHIYAR,  P.O- TOPCHANCHI, P.S- TOPC...
# 2  22449                                  Bhuna Road Tohana
# 3  13438                   DHAMPUR DEGREE COLLEGE , DHAMPUR
# 4  13376                      dhampur law college , DHAMPUR
#
#                                 address_line2        city  state_code  \
# 0  P.Box 968 Bajajnagar MIDC WAluj Aurangabad  South City          27
# 1                               DIST- DHANBAD     DHANBAD          20
# 2                           Bhuna Road Tohana      Tohana           6
# 3                      PAHARI DARWAZA DHAMPUR     DHAMPUR           9
# 4                      pahari darwaza dhampur     dhampur           9
#
#    district_code                     website   area  constructed_area  \
# 0            515             www.yash.org.in   2.50              45.2
# ...

# %%
data=data.drop(columns=['area','constructed_area','year_of_establishment'])

# %%
data.head()
# Out:
#       id                                      address_line1  \
# 0  34256                                         aurangabad
# 1  55441  VILL- SAHUBAHIYAR,  P.O- TOPCHANCHI, P.S- TOPC...
# 2  22449                                  Bhuna Road Tohana
# 3  13438                   DHAMPUR DEGREE COLLEGE , DHAMPUR
# 4  13376                      dhampur law college , DHAMPUR
#
#                                 address_line2        city  state_code  \
# 0  P.Box 968 Bajajnagar MIDC WAluj Aurangabad  South City          27
# 1                               DIST- DHANBAD     DHANBAD          20
# 2                           Bhuna Road Tohana      Tohana           6
# 3                      PAHARI DARWAZA DHAMPUR     DHAMPUR           9
# 4                      pahari darwaza dhampur     dhampur           9
#
#    district_code                     website  nodalofficer_id  university_id  \
# 0            515             www.yash.org.in           193669            298
# ...

# %%
data=data.drop(columns=['nodalofficer_id','statutory_body_id','other_statutory_body','year_of_affiliation'])

# %%
data.head()
# Out:
#       id                                      address_line1  \
# 0  34256                                         aurangabad
# 1  55441  VILL- SAHUBAHIYAR,  P.O- TOPCHANCHI, P.S- TOPC...
# 2  22449                                  Bhuna Road Tohana
# 3  13438                   DHAMPUR DEGREE COLLEGE , DHAMPUR
# 4  13376                      dhampur law college , DHAMPUR
#
#                                 address_line2        city  state_code  \
# 0  P.Box 968 Bajajnagar MIDC WAluj Aurangabad  South City          27
# 1                               DIST- DHANBAD     DHANBAD          20
# 2                           Bhuna Road Tohana      Tohana           6
# 3                      PAHARI DARWAZA DHAMPUR     DHAMPUR           9
# 4                      pahari darwaza dhampur     dhampur           9
#
#    district_code                     website  university_id location  \
# 0            515             www.yash.org.in            298        R
# ...

# %%
data=data.drop(columns=['management_id','offers_loan'])

# %%
data.head()
# Out:
#       id                                      address_line1  \
# 0  34256                                         aurangabad
# 1  55441  VILL- SAHUBAHIYAR,  P.O- TOPCHANCHI, P.S- TOPC...
# 2  22449                                  Bhuna Road Tohana
# 3  13438                   DHAMPUR DEGREE COLLEGE , DHAMPUR
# 4  13376                      dhampur law college , DHAMPUR
#
#                                 address_line2        city  state_code  \
# 0  P.Box 968 Bajajnagar MIDC WAluj Aurangabad  South City          27
# 1                               DIST- DHANBAD     DHANBAD          20
# 2                           Bhuna Road Tohana      Tohana           6
# 3                      PAHARI DARWAZA DHAMPUR     DHAMPUR           9
# 4                      pahari darwaza dhampur     dhampur           9
#
#    district_code                     website  university_id location  \
# 0            515             www.yash.org.in            298        R
# ...

# %%
data.columns
# Out:
# Index(['id', 'address_line1', 'address_line2', 'city', 'state_code',
#        'district_code', 'website', 'university_id', 'location', 'autonomous',
#        'specialized', 'other_speciality', 'evening', 'girl_exclusive',
#        'staff_quarter_available', 'staff_quarter_id',
#        'student_hostel_available', 'no_of_student_hostel', 'speciality_id',
#        'name', 'survey_year', 'financial_income_id',
#        'financial_expenditure_id', 'infrastructure_id', 'remarks', 'latitude',
#        'longitude', 'scholarship_id', 'loan_id', 'is_accredited',
#        'is_foreign_students_enrolled', 'offers_scholarship',
#        'has_diploma_courses', 'diploma_course_id', 'college_type_id',
#        'pin_code', 'has_fellowships', 'fellowships_id',
#        'other_affiliated_university_id', 'has_other_minority_data'],
#       dtype='object')

# %%
data=data.drop(columns=['staff_quarter_available','staff_quarter_id','financial_income_id','financial_expenditure_id'])

# %%
data.columns
# Out:
# Index(['id', 'address_line1', 'address_line2', 'city', 'state_code',
#        'district_code', 'website', 'university_id', 'location', 'autonomous',
#        'specialized', 'other_speciality', 'evening', 'girl_exclusive',
#        'student_hostel_available', 'no_of_student_hostel', 'speciality_id',
#        'name', 'survey_year', 'infrastructure_id', 'remarks', 'latitude',
#        'longitude', 'scholarship_id', 'loan_id', 'is_accredited',
#        'is_foreign_students_enrolled', 'offers_scholarship',
#        'has_diploma_courses', 'diploma_course_id', 'college_type_id',
#        'pin_code', 'has_fellowships', 'fellowships_id',
#        'other_affiliated_university_id', 'has_other_minority_data'],
#       dtype='object')

# %%
data=data.drop(columns=['other_speciality','survey_year','remarks','scholarship_id','loan_id','is_accredited','is_foreign_students_enrolled','has_diploma_courses','diploma_course_id','fellowships_id','other_affiliated_university_id','has_other_minority_data'])

# %%
data.head()
# Out:
#       id                                      address_line1  \
# 0  34256                                         aurangabad
# 1  55441  VILL- SAHUBAHIYAR,  P.O- TOPCHANCHI, P.S- TOPC...
# 2  22449                                  Bhuna Road Tohana
# 3  13438                   DHAMPUR DEGREE COLLEGE , DHAMPUR
# 4  13376                      dhampur law college , DHAMPUR
#
#                                 address_line2        city  state_code  \
# 0  P.Box 968 Bajajnagar MIDC WAluj Aurangabad  South City          27
# 1                               DIST- DHANBAD     DHANBAD          20
# 2                           Bhuna Road Tohana      Tohana           6
# 3                      PAHARI DARWAZA DHAMPUR     DHAMPUR           9
# 4                      pahari darwaza dhampur     dhampur           9
#
#    district_code                     website  university_id location  \
# 0            515             www.yash.org.in            298        R
# ...

# %%
data=data.values

# %%
print(data.shape)
# Out:
# (35187, 24)

# %%
infra=pd.read_csv("./2015_16_infrastructure.csv")

# %%
infra.head()
# Out:
#        id  playground  auditorium  theatre  library  laboratory  \
# 0  185131        True       False    False     True        True
# 1  202094        True       False     True     True       False
# 2  197414        True        True    False     True        True
# 3  164444        True       False    False     True        True
# 4  188887        True        True    False     True       False
#
#    conference_hall  health_center  gymnasium_fitness_center  indoor_stadium  \
# 0             True          False                     False           False
# 1            False          False                     False           False
# 2             True           True                     False            True
# 3             True          False                     False           False
# 4             True           True                     False           False
#
#          ...         no_of_separate_rooms_for_girls  solar_power_generation  \
# ...

# %%
infra.columns
# Out:
# Index(['id', 'playground', 'auditorium', 'theatre', 'library', 'laboratory',
#        'conference_hall', 'health_center', 'gymnasium_fitness_center',
#        'indoor_stadium', 'common_room', 'computer_center', 'cafeteria',
#        'guest_house', 'no_of_playgrounds', 'no_of_auditoriums',
#        'no_of_theatres', 'no_of_libraries', 'no_of_laboratories',
#        'no_of_conference_halls', 'no_of_health_centers',
#        'no_of_gymnasim_fitness_centers', 'no_of_indoor_stadiums',
#        'no_of_common_rooms', 'no_of_computer_centers', 'no_of_cafeteria',
#        'no_of_guest_houses', 'separate_room_for_girls',
#        'no_of_separate_rooms_for_girls', 'solar_power_generation',
#        'connectivity_nkn', 'connectivity_nmeict', 'no_of_books',
#        'no_of_journals', 'campus_friendly', 'grievance_redressal_mechanism',
#        'vigilance_cell', 'opportunity_cell'],
#       dtype='object')

# %%
infra=infra.drop(columns=['playground','theatre','gymnasium_fitness_center','indoor_stadium','common_room','cafeteria','guest_house'
                         ,'no_of_playgrounds','no_of_theatres','no_of_gymnasim_fitness_centers','no_of_indoor_stadiums','no_of_common_rooms'
                         ,'no_of_cafeteria','no_of_guest_houses','separate_room_for_girls','no_of_separate_rooms_for_girls','solar_power_generation',
                         'connectivity_nkn','connectivity_nmeict','no_of_books','no_of_journals','campus_friendly','grievance_redressal_mechanism','vigilance_cell','opportunity_cell'])

# %%
infra.head()
# Out:
#        id  auditorium  library  laboratory  conference_hall  health_center  \
# 0  185131       False     True        True             True          False
# 1  202094       False     True       False            False          False
# 2  197414        True     True        True             True           True
# 3  164444       False     True        True             True          False
# 4  188887        True     True       False             True           True
#
#    computer_center  no_of_auditoriums  no_of_libraries  no_of_laboratories  \
# 0             True                NaN              1.0                 3.0
# 1             True                NaN              1.0                 NaN
# 2             True                1.0              1.0                 1.0
# 3             True                NaN              1.0                 4.0
# 4             True                1.0              1.0                 NaN
#
# ...

# %%
infra.columns
# Out:
# Index(['id', 'auditorium', 'library', 'laboratory', 'conference_hall',
#        'health_center', 'computer_center', 'no_of_auditoriums',
#        'no_of_libraries', 'no_of_laboratories', 'no_of_conference_halls',
#        'no_of_health_centers', 'no_of_computer_centers'],
#       dtype='object')

# %%
infra=infra.values

# %%
infra.shape
# Out:
# (43085, 13)

# %%
data.shape
# Out:
# (35187, 24)

# %%
college=pd.read_csv("./2015_16_college.csv")

# %%
college.head()
# Out:
#       id                                               name  university_id  \
# 0   5935  Shri R. P. Arts, Shri K. B. Commerce and Smt. ...            148
# 1  13021                                      Swift College            408
# 2  13022                             R.S.V.V.S.P.S. College            408
# 3   5795                       U. T. S. Mahila Arts College            148
# 4  52973                                        M D College            510
#
#    district_code  state_code  type_id  survey_year  is_dcf_applicable
# 0            482          24        1         2015               True
# 1            122           8        1         2015               True
# 2            119           8        1         2015               True
# 3            483          24        1         2015               True
# 4            176           9        1         2015               True

# %%
college=college.drop(columns=['survey_year','is_dcf_applicable'])

# %%
college.head()
# Out:
#       id                                               name  university_id  \
# 0   5935  Shri R. P. Arts, Shri K. B. Commerce and Smt. ...            148
# 1  13021                                      Swift College            408
# 2  13022                             R.S.V.V.S.P.S. College            408
# 3   5795                       U. T. S. Mahila Arts College            148
# 4  52973                                        M D College            510
#
#    district_code  state_code  type_id
# 0            482          24        1
# 1            122           8        1
# 2            119           8        1
# 3            483          24        1
# 4            176           9        1

# %%
college.columns
# Out:
# Index(['id', 'name', 'university_id', 'district_code', 'state_code',
#        'type_id'],
#       dtype='object')

# %%
college=college.values

# %%
print(college.shape)
# Out:
# (41477, 6)

# %%
course=pd.read_csv("./2015_16_course.csv")
# Out:
# /home/ambika/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
course.head()
# Out:
#        id  mode_id  only_through_colleges  level_id  programme_id  \
# 0  949531        1                  False         1           157
# 1  949532        1                  False         3           111
# 2  949533        1                  False         6            82
# 3  949534        1                  False         4           180
# 4  957860        1                  False         8            39
#
#      discipline  broad_discipline_group  intake  no_of_applicants  \
# 0  Horticulture                       5     8.0               NaN
# 1  Horticulture                       5    51.0               NaN
# 2  Horticulture                       5    99.0               NaN
# 3   Horticuture                     107   187.0               NaN
# 4           Law                      52   144.0               NaN
#
#    duration_year  duration_month  type_id  examination_system_id  \
# 0              3               0        1                      2
# ...

# %%
course.columns
# Out:
# Index(['id', 'mode_id', 'only_through_colleges', 'level_id', 'programme_id',
#        'discipline', 'broad_discipline_group', 'intake', 'no_of_applicants',
#        'duration_year', 'duration_month', 'type_id', 'examination_system_id',
#        'approving_statutory_body_id', 'approving_university_id',
#        'broad_discipline_group_category_id', 'admission_criterion_id'],
#       dtype='object')

# %%
course=course.drop(columns=['examination_system_id','approving_statutory_body_id','admission_criterion_id'])

# %%
course.head()
# Out:
#        id  mode_id  only_through_colleges  level_id  programme_id  \
# 0  949531        1                  False         1           157
# 1  949532        1                  False         3           111
# 2  949533        1                  False         6            82
# 3  949534        1                  False         4           180
# 4  957860        1                  False         8            39
#
#      discipline  broad_discipline_group  intake  no_of_applicants  \
# 0  Horticulture                       5     8.0               NaN
# 1  Horticulture                       5    51.0               NaN
# 2  Horticulture                       5    99.0               NaN
# 3   Horticuture                     107   187.0               NaN
# 4           Law                      52   144.0               NaN
#
#    duration_year  duration_month  type_id approving_university_id  \
# 0              3               0        1                     NaN
# ...

# %%
course=course.values

# %%
print(course.shape)
# Out:
# (210015, 14)
