# %%
import pandas as pd
import numpy as np

# %%
infra=pd.read_csv("./2015_16_infrastructure.csv")

# %%
infra=infra.drop(columns=['playground','theatre','gymnasium_fitness_center','indoor_stadium','common_room','cafeteria','guest_house'
                         ,'no_of_playgrounds','no_of_theatres','no_of_gymnasim_fitness_centers','no_of_indoor_stadiums','no_of_common_rooms'
                         ,'no_of_cafeteria','no_of_guest_houses','separate_room_for_girls','no_of_separate_rooms_for_girls','solar_power_generation',
                         'connectivity_nkn','connectivity_nmeict','no_of_books','no_of_journals','campus_friendly','grievance_redressal_mechanism','vigilance_cell','opportunity_cell'])

# %%
infra=infra.drop(columns=['library',])

# %%
infra.head()
# Out:
#        id  auditorium  laboratory  conference_hall  health_center  \
# 0  185131       False        True             True          False
# 1  202094       False       False            False          False
# 2  197414        True        True             True           True
# 3  164444       False        True             True          False
# 4  188887        True       False             True           True
#
#    computer_center  no_of_auditoriums  no_of_libraries  no_of_laboratories  \
# 0             True                NaN              1.0                 3.0
# 1             True                NaN              1.0                 NaN
# 2             True                1.0              1.0                 1.0
# 3             True                NaN              1.0                 4.0
# 4             True                1.0              1.0                 NaN
#
#    no_of_conference_halls  no_of_health_centers  no_of_computer_centers
# ...

# %%
infra=infra.drop(columns=['auditorium','no_of_auditoriums'])

# %%
infra.head()
# Out:
#        id  laboratory  conference_hall  health_center  computer_center  \
# 0  185131        True             True          False             True
# 1  202094       False            False          False             True
# 2  197414        True             True           True             True
# 3  164444        True             True          False             True
# 4  188887       False             True           True             True
#
#    no_of_libraries  no_of_laboratories  no_of_conference_halls  \
# 0              1.0                 3.0                     1.0
# 1              1.0                 NaN                     NaN
# 2              1.0                 1.0                     1.0
# 3              1.0                 4.0                     1.0
# 4              1.0                 NaN                     1.0
#
#    no_of_health_centers  no_of_computer_centers
# 0                   NaN                     1.0
# 1                   NaN                     1.0
# ...

# %%
infra=infra.fillna(value=0)

# %%
infra.head()
# Out:
#        id  laboratory  conference_hall  health_center  computer_center  \
# 0  185131        True             True          False             True
# 1  202094       False            False          False             True
# 2  197414        True             True           True             True
# 3  164444        True             True          False             True
# 4  188887       False             True           True             True
#
#    no_of_libraries  no_of_laboratories  no_of_conference_halls  \
# 0              1.0                 3.0                     1.0
# 1              1.0                 0.0                     0.0
# 2              1.0                 1.0                     1.0
# 3              1.0                 4.0                     1.0
# 4              1.0                 0.0                     1.0
#
#    no_of_health_centers  no_of_computer_centers
# 0                   0.0                     1.0
# 1                   0.0                     1.0
# ...

# %%
infra=infra.applymap(func=lambda x: 1 if x == True else x)

# %%
infra=infra.applymap(func=lambda x: 0 if x == False else x)

# %%
infra.head()
# Out:
#        id  laboratory  conference_hall  health_center  computer_center  \
# 0  185131           1                1              0                1
# 1  202094           0                0              0                1
# 2  197414           1                1              1                1
# 3  164444           1                1              0                1
# 4  188887           0                1              1                1
#
#    no_of_libraries  no_of_laboratories  no_of_conference_halls  \
# 0              1.0                 3.0                     1.0
# 1              1.0                 0.0                     0.0
# 2              1.0                 1.0                     1.0
# 3              1.0                 4.0                     1.0
# 4              1.0                 0.0                     1.0
#
#    no_of_health_centers  no_of_computer_centers
# 0                   0.0                     1.0
# 1                   0.0                     1.0
# ...

# %%
infra=infra.drop(columns=['laboratory','conference_hall','health_center','health_center','computer_center'])

# %%
infra=infra.to_csv('infrastructure.csv')

# %%
a=[[1,2,3],2,3,4]
