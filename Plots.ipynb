# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
disc=pd.read_csv('./Frequency_Discipline.csv')

# %%
disc.head()
# Out:
#    Unnamed: 0  id       discipline_group_category  freq_PG  freq_UG  \
# 0           0   1                     Agriculture      252      386
# 1           1   2                    Area Studies      745      362
# 2           2   3                        Commerce     2775    13317
# 3           3   4  Criminology & Forensic Science        3        5
# 4           4   5                 Defence Studies       31       11
#
#    freq_Integrated  freq_Certificate  freq_Diploma  freq_PGDiploma  \
# 0                0                 3            20               0
# 1                0                24            13              12
# 2                0                48            59              52
# 3                0                 0             0               1
# 4                0                16             9               1
#
#    freq_MPhill  freq_PHD
# 0            1       103
# 1           54        44
# 2          232       177
# 3            0         0
# ...

# %%
disc.plot(x="discipline_group_category", y="freq_UG", kind="bar",figsize=(12, 10))

# %%
disc.plot(x="discipline_group_category", y="freq_PHD", kind="bar",figsize=(12, 10))

# %%
disc.plot(x="discipline_group_category", y="freq_Diploma", kind="bar",figsize=(12, 10))

# %%
disc.plot(x="discipline_group_category", y="freq_PGDiploma", kind="bar",figsize=(12, 10))

# %%
disc.plot(x="discipline_group_category", y="freq_MPhill", kind="bar",figsize=(12, 10))

# %%
disc.plot(x="discipline_group_category", y="freq_Certificate", kind="bar",figsize=(12, 10))

# %%
disc.plot(x="discipline_group_category", y="freq_Integrated", kind="bar",figsize=(12, 10))

# %%
disc.head()
# Out:
#    Unnamed: 0  id       discipline_group_category  freq_PG  freq_UG  \
# 0           0   1                     Agriculture      252      386
# 1           1   2                    Area Studies      745      362
# 2           2   3                        Commerce     2775    13317
# 3           3   4  Criminology & Forensic Science        3        5
# 4           4   5                 Defence Studies       31       11
#
#    freq_Integrated  freq_Certificate  freq_Diploma  freq_PGDiploma  \
# 0                0                 3            20               0
# 1                0                24            13              12
# 2                0                48            59              52
# 3                0                 0             0               1
# 4                0                16             9               1
#
#    freq_MPhill  freq_PHD
# 0            1       103
# 1           54        44
# 2          232       177
# 3            0         0
# ...

# %% [markdown]
# # Combined analysis

# %%
plt.figure(figsize=(20,10))
plt.plot( 'discipline_group_category','freq_PG', data=disc, marker='o', markerfacecolor='blue', markersize=5, color='blue', linewidth=1)
plt.legend(disc.index,loc="upper left")

plt.plot( 'discipline_group_category', 'freq_UG', data=disc, marker='o', markerfacecolor='red', markersize=5, color='red', linewidth=1)

plt.plot( 'discipline_group_category', 'freq_PHD', data=disc, marker='o', markerfacecolor='green', markersize=5, color='green', linewidth=1)
# plt.plot( 'discipline_group_category', 'freq_Diploma', data=disc, marker='o', markerfacecolor='k', markersize=5, color='black', linewidth=1)
# plt.plot( 'discipline_group_category', 'freq_PGDiploma', data=disc, marker='o', markerfacecolor='orange', markersize=5, color='orange', linewidth=1)
# plt.plot( 'discipline_group_category', 'freq_MPhill', data=disc, marker='o', markerfacecolor='brown', markersize=5, color='brown', linewidth=1)
# plt.plot( 'discipline_group_category', 'freq_Certificate', data=disc, marker='o', markerfacecolor='violet', markersize=5, color='violet', linewidth=1)
# plt.plot( 'discipline_group_category', 'freq_Integrated', data=disc, marker='o', markerfacecolor='yellow', markersize=5, color='yellow', linewidth=1)
plt.figure(figsize=(100,10))
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot( 'discipline_group_category','freq_PG', data=disc, marker='o', markerfacecolor='blue', markersize=5, color='blue', linewidth=1)
plt.legend('freq_PG',loc="upper left")

plt.plot( 'discipline_group_category', 'freq_UG', data=disc, marker='o', markerfacecolor='red', markersize=5, color='red', linewidth=1)
plt.legend('freq_UG',loc="upper left")
plt.plot( 'discipline_group_category', 'freq_PHD', data=disc, marker='o', markerfacecolor='green', markersize=5, color='green', linewidth=1)
plt.legend('freq_PHD',loc="upper left")
plt.plot( 'discipline_group_category', 'freq_Diploma', data=disc, marker='o', markerfacecolor='k', markersize=5, color='black', linewidth=1)
plt.legend('freq_Diploma',loc="upper left")
plt.plot( 'discipline_group_category', 'freq_PGDiploma', data=disc, marker='o', markerfacecolor='orange', markersize=5, color='orange', linewidth=1)
plt.legend('freq_PGDiploma',loc="upper left")
plt.plot( 'discipline_group_category', 'freq_MPhill', data=disc, marker='o', markerfacecolor='brown', markersize=5, color='brown', linewidth=1)
plt.legend('freq_MPhill',loc="upper left")
plt.plot( 'discipline_group_category', 'freq_Certificate', data=disc, marker='o', markerfacecolor='violet', markersize=5, color='violet', linewidth=1)
plt.legend('freq_Certificate',loc="upper left")
plt.plot( 'discipline_group_category', 'freq_Integrated', data=disc, marker='o', markerfacecolor='yellow', markersize=5, color='yellow', linewidth=1)
plt.legend('freq_Integrated',loc="upper left")
